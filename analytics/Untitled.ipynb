# %%
import pandas as pd
import numpy as np

import sys
sys.path.append("..")
from lib.thresholds import FileThresholdSet

# %%
thresholds = FileThresholdSet(["/Users/martin/Downloads/tsim-blr-win01_AllInstanceThresholdSettings_2020_07_26_19_15_45.csv"])
thresholds.load()
# Out:
# 2020-08-31 12:50:07,608 - lib.thresholds - INFO - Loading Server Thresholds from '/Users/martin/Downloads/tsim-blr-win01_AllInstanceThresholdSettings_2020_07_26_19_15_45.csv' ...

# %%
t = pd.DataFrame(thresholds.set)

# %%
t
# Out:
#                     agent  port monitorType              device instance  \
# 0      pa-blr-lnx104_9078  9078         CPU  pa-blr-lnx104_9078      CPU
# 1      pa-blr-lnx104_9078  9078         CPU  pa-blr-lnx104_9078      CPU
# 2      pa-blr-lnx104_9078  9078         CPU  pa-blr-lnx104_9078      CPU
# 3      pa-blr-lnx104_9078  9078         CPU  pa-blr-lnx104_9078      CPU
# 4      pa-blr-lnx104_9078  9078         CPU  pa-blr-lnx104_9078      CPU
# ...                   ...   ...         ...                 ...      ...
# 61324  pa-blr-lnx100_9096  9096      MEMORY  pa-blr-lnx100_9096   MEMORY
# 61325  pa-blr-lnx100_9096  9096      MEMORY  pa-blr-lnx100_9096   MEMORY
# 61326  pa-blr-lnx100_9096  9096      MEMORY  pa-blr-lnx100_9096   MEMORY
# 61327  pa-blr-lnx100_9096  9096      MEMORY  pa-blr-lnx100_9096   MEMORY
# 61328  pa-blr-lnx100_9096  9096      MEMORY  pa-blr-lnx100_9096   MEMORY
#
#                    attribute  severity duration condition   value      uom  \
# 0                     CPUInt  CRITICAL        5         >     1.0  intrpts
# 1            CPUPoolEntlUtil  CRITICAL        5         >    40.0        %
# 2      CPUSharedPoolIdleTime  CRITICAL        5         >    60.0        %
# 3                CPUPoolUtil  CRITICAL        5         >  4000.0        %
# 4           CPUVMReservation  CRITICAL        5         >    60.0      GHz
# ...                      ...       ...      ...       ...     ...      ...
# 61324         MEMUsedMemPerc  CRITICAL        5         >    95.0        %
# 61325           MEMFreeMemMB  CRITICAL        5         >    95.0       MB
# 61326              MEMVMUsed  CRITICAL        5         >    95.0       MB
# 61327       MEMVMReservation  CRITICAL        5         >    95.0       MB
# 61328            MEMVMMapped  CRITICAL        5         >    95.0       MB
#
#       outsideBasline autoClose predict minSampleWindow baselineType  \
# 0      Auto Baseline      true   false            None
# 1      Auto Baseline      true   false            None
# 2      Auto Baseline      true   false            None
# 3      Auto Baseline      true   false            None
# 4      Auto Baseline      true   false            None
# ...              ...       ...     ...             ...          ...
# 61324  Auto Baseline      true    true            None
# 61325  Auto Baseline      true    true            None
# 61326  Auto Baseline      true    true            None
# 61327  Auto Baseline      true    true            None
# 61328  Auto Baseline      true    true            None
#
#       absoluteDeviation deviation suppressEvents thresholdType
# 0                  None                    false      absolute
# 1                  None                    false      absolute
# 2                  None                    false      absolute
# 3                  None                    false      absolute
# 4                  None                    false      absolute
# ...                 ...       ...            ...           ...
# 61324              None                    false      absolute
# 61325              None                    false      absolute
# 61326              None                    false      absolute
# 61327              None                    false      absolute
# 61328              None                    false      absolute
#
# [61329 rows x 20 columns]
