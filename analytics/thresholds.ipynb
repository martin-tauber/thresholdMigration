# %%
import pandas as pd
import numpy as np

import sys
sys.path.append("..")
from lib.thresholds import FileThresholdSet, InstanceThresholdMigrator
from lib.kmrepository import KMRepository
from lib.policy import PolicyFactory
from lib.solution import SolutionPackManager
from lib.ruleset import RuleSetFactory, RulesetMigrator

# %%
kmRepository = KMRepository.get(cachedir="../cache")

thresholds = FileThresholdSet(["/Users/martin/Downloads/InstanceThresholdsSanofi_E21_E111/XSPW12B871C_E11-1_AllInstanceThresholdSettings_2020_09_15_16_36_46.csv"])
thresholds.load()
migrator = InstanceThresholdMigrator(thresholds, kmRepository)
agentConfigurations = migrator.migrate(False)

policyFactory = PolicyFactory("ALL", "*", "*", False, False, 399, 499, "admin", "administrators")
# Out:
# 2020-09-18 09:57:52,162 - lib.kmrepository - INFO - Loading KM repository from cache '../cache/11.3.03' ...
# 2020-09-18 09:57:52,214 - lib.thresholds - INFO - Loading Server Thresholds from '/Users/martin/Downloads/InstanceThresholdsSanofi_E21_E111/XSPW12B871C_E11-1_AllInstanceThresholdSettings_2020_09_15_16_36_46.csv' ...
# 2020-09-18 09:57:52,310 - lib.thresholds - INFO - Migrating 1174 instance thresholds ...
# 2020-09-18 09:57:52,317 - lib.thresholds - WARNING - Monitor SW_FILES not found in repository.
# 2020-09-18 09:57:52,318 - lib.thresholds - WARNING - Monitor SW_FOLDERS not found in repository.
# 2020-09-18 09:57:52,319 - lib.thresholds - WARNING - Monitor SW_NTSERVICES not found in repository.
# 2020-09-18 09:57:52,319 - lib.thresholds - WARNING - Monitor SW_NUMBERS not found in repository.
# 2020-09-18 09:57:52,320 - lib.thresholds - WARNING - Monitor SW_OSCOMMANDS not found in repository.
# 2020-09-18 09:57:52,321 - lib.thresholds - WARNING - Monitor SW_PROCESSES not found in repository.

# %%
(c, configurations) = policyFactory.optimizer.createConfigurationMatrix(agentConfigurations)
# Out:
# 2020-09-18 09:58:06,919 - lib.optimizer - INFO - Optimizing policies for 175 agents and 1039 unique configurations. Using 8 threads and a depth of 3.

# %%
c
# Out:
#           _solution_   _monitorType_  xspl50p507s.pharma.aventis.com:3181  \
# 0            pukepd1             CPU                                 True
# 1            pukepd1             CPU                                 True
# 2            pukepd1             CPU                                False
# 3            pukepd1             CPU                                False
# 4            pukepd1             CPU                                False
# ...              ...             ...                                  ...
# 1034  pkm_postgresql  PGR_DB_METRICS                                False
# 1035  pkm_postgresql  PGR_DB_METRICS                                False
# 1036  pkm_postgresql  PGR_DB_METRICS                                False
# 1037  pkm_postgresql  PGR_DB_METRICS                                False
# 1038             vsm   VSM_DATASTORE                                False
#
#       xspl50b177t.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                    True
# 3                                    True
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xspl50b176k.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                    True
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsnh11p803c.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsnh10p904p.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xspl11b346s.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsnh11c741k.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsnl10s696c.pharma.aventis.com:3181  ...  \
# 0                                   False  ...
# 1                                   False  ...
# 2                                   False  ...
# 3                                   False  ...
# 4                                   False  ...
# ...                                   ...  ...
# 1034                                False  ...
# 1035                                False  ...
# 1036                                False  ...
# 1037                                False  ...
# 1038                                False  ...
#
#       XSPW50T336C.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       XSPW11X086X.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsph11b307p.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xspl11c529a.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsph11f489k.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsph11c046w.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsph11a257s.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsph11c996a.pharma.aventis.com:3181  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1034                                False
# 1035                                False
# 1036                                False
# 1037                                False
# 1038                                False
#
#       xsph11a431c.pharma.aventis.com:3181  REMOTEAG_VMW_E11-1:3184
# 0                                   False                    False
# 1                                   False                    False
# 2                                   False                    False
# 3                                   False                    False
# 4                                   False                    False
# ...                                   ...                      ...
# 1034                                False                    False
# 1035                                False                    False
# 1036                                False                    False
# 1037                                False                    False
# 1038                                False                     True
#
# [1039 rows x 177 columns]

# %%
c[c.columns.tolist()] == True
# Out:
#     _solution_  _monitorType_  pa-blr-lnx104_9078:9078  \
# 0        False          False                     True
# 1        False          False                     True
# 2        False          False                     True
# 3        False          False                     True
# 4        False          False                     True
# 5        False          False                     True
# 6        False          False                     True
# 7        False          False                     True
# 8        False          False                     True
# 9        False          False                     True
# 10       False          False                     True
# 11       False          False                     True
# 12       False          False                     True
# 13       False          False                     True
# 14       False          False                     True
# 15       False          False                     True
# 16       False          False                     True
# 17       False          False                     True
# 18       False          False                     True
# 19       False          False                     True
# 20       False          False                     True
# 21       False          False                     True
# 22       False          False                     True
# 23       False          False                     True
# 24       False          False                     True
# 25       False          False                     True
# 26       False          False                     True
#
#     pa-blr-lnx108_9013:9013  pa-blr-lnx102_9083:9083  pa-blr-lnx103_9033:9033  \
# 0                      True                     True                     True
# 1                      True                     True                     True
# 2                      True                     True                     True
# 3                      True                     True                     True
# 4                      True                     True                     True
# 5                      True                     True                     True
# 6                      True                     True                     True
# 7                      True                     True                     True
# 8                      True                     True                     True
# 9                      True                     True                     True
# 10                     True                     True                     True
# 11                     True                     True                     True
# 12                     True                     True                     True
# 13                     True                     True                     True
# 14                     True                     True                     True
# 15                     True                     True                     True
# 16                     True                     True                     True
# 17                     True                     True                     True
# 18                     True                     True                     True
# 19                     True                     True                     True
# 20                     True                     True                     True
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx101_9087:9087  pa-blr-lnx105_9092:9092  pa-blr-lnx101_9016:9016  \
# 0                      True                     True                     True
# 1                      True                     True                     True
# 2                      True                     True                     True
# 3                      True                     True                     True
# 4                      True                     True                     True
# 5                      True                     True                     True
# 6                      True                     True                     True
# 7                      True                     True                     True
# 8                      True                     True                     True
# 9                      True                     True                     True
# 10                     True                     True                     True
# 11                     True                     True                     True
# 12                     True                     True                     True
# 13                     True                     True                     True
# 14                     True                     True                     True
# 15                     True                     True                     True
# 16                     True                     True                     True
# 17                     True                     True                     True
# 18                     True                     True                     True
# 19                     True                     True                     True
# 20                     True                     True                     True
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx106_9027:9027  ...  pa-blr-lnx107_9058:9058  \
# 0                      True  ...                    False
# 1                      True  ...                    False
# 2                      True  ...                    False
# 3                      True  ...                    False
# 4                      True  ...                    False
# 5                      True  ...                    False
# 6                      True  ...                    False
# 7                      True  ...                    False
# 8                      True  ...                    False
# 9                      True  ...                    False
# 10                     True  ...                    False
# 11                     True  ...                    False
# 12                     True  ...                    False
# 13                     True  ...                    False
# 14                     True  ...                    False
# 15                     True  ...                    False
# 16                     True  ...                    False
# 17                     True  ...                    False
# 18                     True  ...                    False
# 19                     True  ...                    False
# 20                     True  ...                    False
# 21                     True  ...                     True
# 22                     True  ...                     True
# 23                     True  ...                     True
# 24                     True  ...                     True
# 25                     True  ...                     True
# 26                     True  ...                     True
#
#     pa-blr-lnx104_9003:9003  pa-blr-lnx101_9053:9053  pa-blr-lnx100_9032:9032  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
# 10                    False                    False                    False
# 11                    False                    False                    False
# 12                    False                    False                    False
# 13                    False                    False                    False
# 14                    False                    False                    False
# 15                    False                    False                    False
# 16                    False                    False                    False
# 17                    False                    False                    False
# 18                    False                    False                    False
# 19                    False                    False                    False
# 20                    False                    False                    False
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx102_9068:9068  pa-blr-lnx104_9062:9062  pa-blr-lnx102_9097:9097  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
# 10                    False                    False                    False
# 11                    False                    False                    False
# 12                    False                    False                    False
# 13                    False                    False                    False
# 14                    False                    False                    False
# 15                    False                    False                    False
# 16                    False                    False                    False
# 17                    False                    False                    False
# 18                    False                    False                    False
# 19                    False                    False                    False
# 20                    False                    False                    False
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx102_9059:9059  pa-blr-lnx104_9099:9099  pa-blr-lnx100_9081:9081
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
# 10                    False                    False                    False
# 11                    False                    False                    False
# 12                    False                    False                    False
# 13                    False                    False                    False
# 14                    False                    False                    False
# 15                    False                    False                    False
# 16                    False                    False                    False
# 17                    False                    False                    False
# 18                    False                    False                    False
# 19                    False                    False                    False
# 20                    False                    False                    False
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
# [27 rows x 2545 columns]

# %%
for name, group in d.groupby(["_environment_"]):
    print(name)
# Out:
# Production
# Test

# %%
#matrix = configurationMatrix
s = (matrix[matrix.columns.tolist()] == True).sum(axis = 0)
s.loc[s>0].index.tolist()
# Out:
# ['pa-blr-lnx104_9078:9078',
#  'pa-blr-lnx108_9013:9013',
#  'pa-blr-lnx102_9083:9083',
#  'pa-blr-lnx103_9033:9033',
#  'pa-blr-lnx101_9087:9087',
#  'pa-blr-lnx105_9092:9092',
#  'pa-blr-lnx101_9016:9016',
#  'pa-blr-lnx106_9027:9027',
#  'pa-blr-lnx103_9014:9014',
#  'pa-blr-lnx106_9061:9061',
#  'pa-blr-lnx103_9032:9032',
#  'pa-blr-lnx102_9063:9063',
#  'pa-blr-lnx102_9100:9100',
#  'pa-blr-lnx103_9010:9010',
#  'pa-blr-lnx102_9028:9028',
#  'pa-blr-lnx102_9071:9071',
#  'pa-blr-lnx105_9041:9041',
#  'pa-blr-lnx108_9051:9051',
#  'pa-blr-lnx103_9059:9059',
#  'pa-blr-lnx108_9075:9075',
#  'pa-blr-lnx102_9041:9041',
#  'pa-blr-lnx102_9009:9009',
#  'pa-blr-lnx101_9043:9043',
#  'pa-blr-lnx103_9008:9008',
#  'pa-blr-lnx108_9087:9087',
#  'pa-blr-lnx108_9062:9062',
#  'pa-blr-lnx105_9040:9040',
#  'pa-blr-lnx101_9099:9099',
#  'pa-blr-lnx103_9011:9011',
#  'pa-blr-lnx052_9068:9068',
#  'pa-blr-lnx108_9094:9094',
#  'pa-blr-lnx102_9067:9067',
#  'pa-blr-lnx102_9062:9062',
#  'pa-blr-lnx102_9085:9085',
#  'pa-blr-lnx100_9016:9016',
#  'pa-blr-lnx052_9095:9095',
#  'pa-blr-lnx105_9078:9078',
#  'pa-blr-lnx049_9093:9093',
#  'pa-blr-lnx108_9076:9076',
#  'pa-blr-lnx102_9064:9064',
#  'pa-blr-lnx108_9048:9048',
#  'pa-blr-lnx105_9069:9069',
#  'pa-blr-lnx102_9074:9074',
#  'pa-blr-lnx105_9042:9042',
#  'pa-blr-lnx105_9082:9082',
#  'pa-blr-lnx101_9072:9072',
#  'pa-blr-lnx101_9062:9062',
#  'pa-blr-lnx108_9050:9050',
#  'pa-blr-lnx108_9045:9045',
#  'pa-blr-lnx108_9002:9002',
#  'pa-blr-lnx105_9061:9061',
#  'pa-blr-lnx102_9002:9002',
#  'pa-blr-lnx101_9094:9094',
#  'pa-blr-lnx105_9055:9055',
#  'pa-blr-lnx102_9084:9084',
#  'pa-blr-lnx102_9049:9049',
#  'pa-blr-lnx105_9085:9085',
#  'pa-blr-lnx105_9004:9004',
#  'pa-blr-lnx108_9041:9041',
#  'pa-blr-lnx108_9046:9046',
#  'pa-blr-lnx102_9055:9055',
#  'pa-blr-lnx102_9076:9076',
#  'pa-blr-lnx105_9045:9045',
#  'pa-blr-lnx105_9036:9036',
#  'pa-blr-lnx108_9091:9091',
#  'pa-blr-lnx105_9067:9067',
#  'pa-blr-lnx108_9056:9056',
#  'pa-blr-lnx105_9022:9022',
#  'pa-blr-lnx105_9088:9088',
#  'pa-blr-lnx102_9007:9007',
#  'pa-blr-lnx102_9001:9001',
#  'pa-blr-lnx105_9051:9051',
#  'pa-blr-lnx105_9023:9023',
#  'pa-blr-lnx105_9021:9021',
#  'pa-blr-lnx102_9094:9094',
#  'pa-blr-lnx102_9012:9012',
#  'pa-blr-lnx105_9054:9054',
#  'pa-blr-lnx105_9087:9087',
#  'pa-blr-lnx102_9070:9070',
#  'pa-blr-lnx102_9095:9095',
#  'pa-blr-lnx108_9032:9032',
#  'pa-blr-lnx101_9075:9075',
#  'pa-blr-lnx108_9055:9055',
#  'pa-blr-lnx105_9070:9070',
#  'pa-blr-lnx105_9011:9011',
#  'pa-blr-lnx108_9067:9067',
#  'pa-blr-lnx105_9090:9090',
#  'pa-blr-lnx105_9044:9044',
#  'pa-blr-lnx105_9006:9006',
#  'pa-blr-lnx105_9038:9038',
#  'pa-blr-lnx105_9008:9008',
#  'pa-blr-lnx105_9093:9093',
#  'pa-blr-lnx105_9068:9068',
#  'pa-blr-lnx108_9025:9025',
#  'pa-blr-lnx101_9034:9034',
#  'pa-blr-lnx105_9019:9019',
#  'pa-blr-lnx108_9060:9060',
#  'pa-blr-lnx102_9087:9087',
#  'pa-blr-lnx102_9052:9052',
#  'pa-blr-lnx102_9045:9045',
#  'pa-blr-lnx108_9059:9059',
#  'pa-blr-lnx105_9002:9002',
#  'pa-blr-lnx105_9034:9034',
#  'pa-blr-lnx102_9088:9088',
#  'pa-blr-lnx108_9027:9027',
#  'pa-blr-lnx108_9090:9090',
#  'pa-blr-lnx108_9079:9079',
#  'pa-blr-lnx108_9074:9074',
#  'pa-blr-lnx108_9082:9082',
#  'pa-blr-lnx102_9039:9039',
#  'pa-blr-lnx108_9020:9020',
#  'pa-blr-lnx102_9026:9026',
#  'pa-blr-lnx108_9053:9053',
#  'pa-blr-lnx101_9015:9015',
#  'pa-blr-lnx108_9034:9034',
#  'pa-blr-lnx107_9055:9055',
#  'pa-blr-lnx102_9046:9046',
#  'pa-blr-lnx102_9078:9078',
#  'pa-blr-lnx102_9010:9010',
#  'pa-blr-lnx102_9093:9093',
#  'pa-blr-lnx108_9035:9035',
#  'pa-blr-lnx108_9073:9073',
#  'pa-blr-lnx102_9065:9065',
#  'pa-blr-lnx108_9080:9080',
#  'pa-blr-lnx101_9008:9008',
#  'pa-blr-lnx052_9083:9083',
#  'pa-blr-lnx046_9096:9096',
#  'pa-blr-lnx052_9056:9056',
#  'pa-blr-lnx052_9077:9077',
#  'pa-blr-lnx052_9096:9096',
#  'pa-blr-lnx051_9079:9079',
#  'pa-blr-lnx048_9058:9058',
#  'pa-blr-lnx051_9048:9048',
#  'pa-blr-lnx048_9088:9088',
#  'pa-blr-lnx100_9070:9070',
#  'pa-blr-lnx051_9063:9063',
#  'pa-blr-lnx051_9092:9092',
#  'pa-blr-lnx046_9023:9023',
#  'pa-blr-lnx049_9072:9072',
#  'pa-blr-lnx048_9016:9016',
#  'pa-blr-lnx046_9085:9085',
#  'pa-blr-lnx048_9100:9100',
#  'pa-blr-lnx048_9011:9011',
#  'pa-blr-lnx049_9048:9048',
#  'pa-blr-lnx048_9095:9095',
#  'pa-blr-lnx048_9053:9053',
#  'pa-blr-lnx053_9037:9037',
#  'pa-blr-lnx046_9022:9022',
#  'pa-blr-lnx052_9054:9054',
#  'pa-blr-lnx051_9012:9012',
#  'pa-blr-lnx046_9025:9025',
#  'pa-blr-lnx048_9004:9004',
#  'pa-blr-lnx048_9041:9041',
#  'pa-blr-lnx049_9040:9040',
#  'pa-blr-lnx046_9028:9028',
#  'pa-blr-lnx046_9001:9001',
#  'pa-blr-lnx051_9058:9058',
#  'pa-blr-lnx051_9056:9056',
#  'pa-blr-lnx048_9092:9092',
#  'pa-blr-lnx050_9029:9029',
#  'pa-blr-lnx046_9086:9086',
#  'pa-blr-lnx051_9100:9100',
#  'pa-blr-lnx051_9072:9072',
#  'pa-blr-lnx046_9072:9072',
#  'pa-blr-lnx047_9026:9026',
#  'pa-blr-lnx047_9099:9099',
#  'pa-blr-lnx047_9090:9090',
#  'pa-blr-lnx052_9027:9027',
#  'pa-blr-lnx048_9071:9071',
#  'pa-blr-lnx047_9043:9043',
#  'pa-blr-lnx051_9060:9060',
#  'pa-blr-lnx049_9035:9035',
#  'pa-blr-lnx051_9077:9077',
#  'pa-blr-lnx051_9059:9059',
#  'pa-blr-lnx051_9098:9098',
#  'pa-blr-lnx051_9008:9008',
#  'pa-blr-lnx048_9070:9070',
#  'pa-blr-lnx047_9019:9019',
#  'pa-blr-lnx046_9006:9006',
#  'pa-blr-lnx049_9094:9094',
#  'pa-blr-lnx048_9002:9002',
#  'pa-blr-lnx051_9005:9005',
#  'pa-blr-lnx048_9021:9021',
#  'pa-blr-lnx048_9027:9027',
#  'pa-blr-lnx048_9063:9063',
#  'pa-blr-lnx053_9034:9034',
#  'pa-blr-lnx051_9019:9019',
#  'pa-blr-lnx051_9016:9016',
#  'pa-blr-lnx048_9076:9076',
#  'pa-blr-lnx052_9085:9085',
#  'pa-blr-lnx052_9050:9050',
#  'pa-blr-lnx048_9051:9051',
#  'pa-blr-lnx051_9086:9086',
#  'pa-blr-lnx051_9055:9055',
#  'pa-blr-lnx051_9091:9091',
#  'pa-blr-lnx053_9065:9065',
#  'pa-blr-lnx048_9057:9057',
#  'pa-blr-lnx048_9062:9062',
#  'pa-blr-lnx051_9047:9047',
#  'pa-blr-lnx053_9081:9081',
#  'pa-blr-lnx048_9081:9081',
#  'pa-blr-lnx053_9031:9031',
#  'pa-blr-lnx051_9021:9021',
#  'pa-blr-lnx051_9001:9001',
#  'pa-blr-lnx049_9059:9059',
#  'pa-blr-lnx052_9053:9053',
#  'pa-blr-lnx050_9010:9010',
#  'pa-blr-lnx050_9095:9095',
#  'pa-blr-lnx048_9036:9036',
#  'pa-blr-lnx048_9075:9075',
#  'pa-blr-lnx046_9049:9049',
#  'pa-blr-lnx051_9034:9034',
#  'pa-blr-lnx048_9067:9067',
#  'pa-blr-lnx052_9016:9016',
#  'pa-blr-lnx046_9029:9029',
#  'pa-blr-lnx051_9078:9078',
#  'pa-blr-lnx048_9079:9079',
#  'pa-blr-lnx047_9011:9011',
#  'pa-blr-lnx051_9031:9031',
#  'pa-blr-lnx048_9044:9044',
#  'pa-blr-lnx053_9082:9082',
#  'pa-blr-lnx048_9073:9073',
#  'pa-blr-lnx047_9082:9082',
#  'pa-blr-lnx051_9020:9020',
#  'pa-blr-lnx048_9097:9097',
#  'pa-blr-lnx051_9075:9075',
#  'pa-blr-lnx048_9048:9048',
#  'pa-blr-lnx046_9092:9092',
#  'pa-blr-lnx047_9009:9009',
#  'pa-blr-lnx053_9006:9006',
#  'pa-blr-lnx048_9007:9007',
#  'pa-blr-lnx053_9091:9091',
#  'pa-blr-lnx053_9020:9020',
#  'pa-blr-lnx048_9052:9052',
#  'pa-blr-lnx047_9083:9083',
#  'pa-blr-lnx053_9057:9057',
#  'pa-blr-lnx051_9076:9076',
#  'pa-blr-lnx051_9066:9066',
#  'pa-blr-lnx052_9084:9084',
#  'pa-blr-lnx048_9047:9047',
#  'pa-blr-lnx047_9039:9039',
#  'pa-blr-lnx051_9064:9064',
#  'pa-blr-lnx048_9039:9039',
#  'pa-blr-lnx052_9091:9091',
#  'pa-blr-lnx047_9040:9040',
#  'pa-blr-lnx048_9032:9032',
#  'pa-blr-lnx050_9028:9028',
#  'pa-blr-lnx053_9039:9039',
#  'pa-blr-lnx047_9020:9020',
#  'pa-blr-lnx046_9082:9082',
#  'pa-blr-lnx050_9096:9096',
#  'pa-blr-lnx053_9077:9077',
#  'pa-blr-lnx051_9088:9088',
#  'pa-blr-lnx048_9033:9033',
#  'pa-blr-lnx051_9032:9032',
#  'pa-blr-lnx047_9051:9051',
#  'pa-blr-lnx048_9078:9078',
#  'pa-blr-lnx047_9036:9036',
#  'pa-blr-lnx053_9061:9061',
#  'pa-blr-lnx046_9069:9069',
#  'pa-blr-lnx053_9036:9036',
#  'pa-blr-lnx048_9064:9064',
#  'pa-blr-lnx051_9024:9024',
#  'pa-blr-lnx048_9098:9098',
#  'pa-blr-lnx048_9003:9003',
#  'pa-blr-lnx048_9024:9024',
#  'pa-blr-lnx051_9027:9027',
#  'pa-blr-lnx050_9044:9044',
#  'pa-blr-lnx054_9082:9082',
#  'pa-blr-lnx048_9080:9080',
#  'pa-blr-lnx048_9083:9083',
#  'pa-blr-lnx048_9008:9008',
#  'pa-blr-lnx053_9046:9046',
#  'pa-blr-lnx050_9066:9066',
#  'pa-blr-lnx049_9021:9021',
#  'pa-blr-lnx051_9018:9018',
#  'pa-blr-lnx047_9089:9089',
#  'pa-blr-lnx048_9068:9068',
#  'pa-blr-lnx053_9099:9099',
#  'pa-blr-lnx048_9050:9050',
#  'pa-blr-lnx053_9092:9092',
#  'pa-blr-lnx052_9024:9024',
#  'pa-blr-lnx051_9029:9029',
#  'pa-blr-lnx105_9012:9012',
#  'pa-blr-lnx047_9046:9046',
#  'pa-blr-lnx048_9087:9087',
#  'pa-blr-lnx048_9085:9085',
#  'pa-blr-lnx048_9074:9074',
#  'pa-blr-lnx049_9008:9008',
#  'pa-blr-lnx047_9080:9080',
#  'pa-blr-lnx048_9056:9056',
#  'pa-blr-lnx047_9037:9037',
#  'pa-blr-lnx051_9040:9040',
#  'pa-blr-lnx105_9015:9015',
#  'pa-blr-lnx053_9013:9013',
#  'pa-blr-lnx053_9093:9093',
#  'pa-blr-lnx053_9084:9084',
#  'pa-blr-lnx053_9074:9074',
#  'pa-blr-lnx048_9061:9061',
#  'pa-blr-lnx051_9010:9010',
#  'pa-blr-lnx050_9068:9068',
#  'pa-blr-lnx051_9083:9083',
#  'pa-blr-lnx047_9042:9042',
#  'pa-blr-lnx047_9092:9092',
#  'pa-blr-lnx053_9075:9075',
#  'pa-blr-lnx051_9061:9061',
#  'pa-blr-lnx053_9035:9035',
#  'pa-blr-lnx051_9041:9041',
#  'pa-blr-lnx053_9004:9004',
#  'pa-blr-lnx053_9050:9050',
#  'pa-blr-lnx047_9028:9028',
#  'pa-blr-lnx053_9010:9010',
#  'pa-blr-lnx051_9097:9097',
#  'pa-blr-lnx049_9074:9074',
#  'pa-blr-lnx047_9016:9016',
#  'pa-blr-lnx050_9018:9018',
#  'pa-blr-lnx047_9053:9053',
#  'pa-blr-lnx050_9033:9033',
#  'pa-blr-lnx052_9005:9005',
#  'pa-blr-lnx047_9027:9027',
#  'pa-blr-lnx047_9017:9017',
#  'pa-blr-lnx052_9002:9002',
#  'pa-blr-lnx050_9039:9039',
#  'pa-blr-lnx051_9036:9036',
#  'pa-blr-lnx047_9014:9014',
#  'pa-blr-lnx047_9032:9032',
#  'pa-blr-lnx047_9033:9033',
#  'pa-blr-lnx051_9062:9062',
#  'pa-blr-lnx048_9072:9072',
#  'pa-blr-lnx050_9034:9034',
#  'pa-blr-lnx051_9015:9015',
#  'pa-blr-lnx051_9099:9099',
#  'pa-blr-lnx050_9086:9086',
#  'pa-blr-lnx048_9060:9060',
#  'pa-blr-lnx047_9023:9023',
#  'pa-blr-lnx052_9089:9089',
#  'pa-blr-lnx051_9074:9074',
#  'pa-blr-lnx051_9023:9023',
#  'pa-blr-lnx048_9069:9069',
#  'pa-blr-lnx051_9051:9051',
#  'pa-blr-lnx051_9085:9085',
#  'pa-blr-lnx053_9027:9027',
#  'pa-blr-lnx051_9014:9014',
#  'pa-blr-lnx052_9052:9052',
#  'pa-blr-lnx047_9060:9060',
#  'pa-blr-lnx054_9012:9012',
#  'pa-blr-lnx054_9047:9047',
#  'pa-blr-lnx054_9026:9026',
#  'pa-blr-lnx054_9034:9034',
#  'pa-blr-lnx054_9031:9031',
#  'pa-blr-lnx100_9001:9001',
#  'pa-blr-lnx108_9014:9014',
#  'pa-blr-lnx105_9073:9073',
#  'pa-blr-lnx100_9010:9010',
#  'pa-blr-lnx041_9053:9053',
#  'pa-blr-lnx042_9099:9099',
#  'pa-blr-lnx038_9035:9035',
#  'pa-blr-lnx044_9053:9053',
#  'pa-blr-lnx041_9099:9099',
#  'pa-blr-lnx042_9077:9077',
#  'pa-blr-lnx037_9053:9053',
#  'pa-blr-lnx044_9072:9072',
#  'pa-blr-lnx043_9090:9090',
#  'pa-blr-lnx043_9052:9052',
#  'pa-blr-lnx040_9031:9031',
#  'pa-blr-lnx042_9030:9030',
#  'pa-blr-lnx037_9061:9061',
#  'pa-blr-lnx038_9078:9078',
#  'pa-blr-lnx045_9027:9027',
#  'pa-blr-lnx037_9095:9095',
#  'pa-blr-lnx043_9083:9083',
#  'pa-blr-lnx045_9005:9005',
#  'pa-blr-lnx038_9052:9052',
#  'pa-blr-lnx043_9031:9031',
#  'pa-blr-lnx037_9051:9051',
#  'pa-blr-lnx041_9050:9050',
#  'pa-blr-lnx043_9024:9024',
#  'pa-blr-lnx043_9069:9069',
#  'pa-blr-lnx044_9084:9084',
#  'pa-blr-lnx043_9058:9058',
#  'pa-blr-lnx043_9087:9087',
#  'pa-blr-lnx043_9057:9057',
#  'pa-blr-lnx043_9088:9088',
#  'pa-blr-lnx038_9006:9006',
#  'pa-blr-lnx042_9056:9056',
#  'pa-blr-lnx043_9050:9050',
#  'pa-blr-lnx043_9063:9063',
#  'pa-blr-lnx037_9030:9030',
#  'pa-blr-lnx038_9072:9072',
#  'pa-blr-lnx045_9086:9086',
#  'pa-blr-lnx043_9092:9092',
#  'pa-blr-lnx043_9068:9068',
#  'pa-blr-lnx038_9085:9085',
#  'pa-blr-lnx043_9013:9013',
#  'pa-blr-lnx038_9045:9045',
#  'pa-blr-lnx038_9017:9017',
#  'pa-blr-lnx043_9021:9021',
#  'pa-blr-lnx038_9010:9010',
#  'pa-blr-lnx043_9005:9005',
#  'pa-blr-lnx038_9001:9001',
#  'pa-blr-lnx044_9066:9066',
#  'pa-blr-lnx043_9074:9074',
#  'pa-blr-lnx038_9070:9070',
#  'pa-blr-lnx038_9074:9074',
#  'pa-blr-lnx037_9046:9046',
#  'pa-blr-lnx043_9025:9025',
#  'pa-blr-lnx043_9001:9001',
#  'pa-blr-lnx043_9034:9034',
#  'pa-blr-lnx038_9018:9018',
#  'pa-blr-lnx043_9084:9084',
#  'pa-blr-lnx043_9014:9014',
#  'pa-blr-lnx043_9049:9049',
#  'pa-blr-lnx043_9078:9078',
#  'pa-blr-lnx038_9060:9060',
#  'pa-blr-lnx038_9005:9005',
#  'pa-blr-lnx038_9003:9003',
#  'pa-blr-lnx038_9083:9083',
#  'pa-blr-lnx038_9068:9068',
#  'pa-blr-lnx038_9032:9032',
#  'pa-blr-lnx043_9055:9055',
#  'pa-blr-lnx043_9060:9060',
#  'pa-blr-lnx044_9058:9058',
#  'pa-blr-lnx037_9008:9008',
#  'pa-blr-lnx043_9041:9041',
#  'pa-blr-lnx038_9099:9099',
#  'pa-blr-lnx043_9002:9002',
#  'pa-blr-lnx043_9003:9003',
#  'pa-blr-lnx038_9002:9002',
#  'pa-blr-lnx041_9078:9078',
#  'pa-blr-lnx037_9090:9090',
#  'pa-blr-lnx041_9023:9023',
#  'pa-blr-lnx038_9058:9058',
#  'pa-blr-lnx044_9080:9080',
#  'pa-blr-lnx038_9064:9064',
#  'pa-blr-lnx038_9066:9066',
#  'pa-blr-lnx038_9041:9041',
#  'pa-blr-lnx043_9044:9044',
#  'pa-blr-lnx038_9062:9062',
#  'pa-blr-lnx038_9020:9020',
#  'pa-blr-lnx038_9055:9055',
#  'pa-blr-lnx041_9098:9098',
#  'pa-blr-lnx044_9089:9089',
#  'pa-blr-lnx043_9079:9079',
#  'pa-blr-lnx044_9085:9085',
#  'pa-blr-lnx038_9100:9100',
#  'pa-blr-lnx044_9015:9015',
#  'pa-blr-lnx038_9046:9046',
#  'pa-blr-lnx041_9017:9017',
#  'pa-blr-lnx041_9057:9057',
#  'pa-blr-lnx041_9056:9056',
#  'pa-blr-lnx043_9056:9056',
#  'pa-blr-lnx045_9088:9088',
#  'pa-blr-lnx044_9021:9021',
#  'pa-blr-lnx044_9076:9076',
#  'pa-blr-lnx044_9033:9033',
#  'pa-blr-lnx044_9020:9020',
#  'pa-blr-lnx037_9027:9027',
#  'pa-blr-lnx044_9075:9075',
#  'pa-blr-lnx043_9089:9089',
#  'pa-blr-lnx045_9094:9094',
#  'pa-blr-lnx045_9038:9038',
#  'pa-blr-lnx043_9015:9015',
#  'pa-blr-lnx037_9047:9047',
#  'pa-blr-lnx043_9028:9028',
#  'pa-blr-lnx038_9042:9042',
#  'pa-blr-lnx041_9006:9006',
#  'pa-blr-lnx041_9063:9063',
#  'pa-blr-lnx044_9079:9079',
#  'pa-blr-lnx045_9037:9037',
#  'pa-blr-lnx044_9095:9095',
#  'pa-blr-lnx044_9007:9007',
#  'pa-blr-lnx041_9082:9082',
#  'pa-blr-lnx044_9091:9091',
#  'pa-blr-lnx041_9019:9019',
#  'pa-blr-lnx038_9065:9065',
#  'pa-blr-lnx037_9054:9054',
#  'pa-blr-lnx041_9035:9035',
#  'pa-blr-lnx043_9075:9075',
#  'pa-blr-lnx045_9092:9092',
#  'pa-blr-lnx038_9056:9056',
#  'pa-blr-lnx039_9093:9093',
#  'pa-blr-lnx038_9050:9050',
#  'pa-blr-lnx044_9045:9045',
#  'pa-blr-lnx043_9011:9011',
#  'pa-blr-lnx041_9020:9020',
#  'pa-blr-lnx038_9004:9004',
#  'pa-blr-lnx041_9028:9028',
#  'pa-blr-lnx038_9048:9048',
#  'pa-blr-lnx038_9073:9073',
#  'pa-blr-lnx038_9025:9025',
#  'pa-blr-lnx038_9067:9067',
#  'pa-blr-lnx045_9087:9087',
#  'pa-blr-lnx045_9080:9080',
#  'pa-blr-lnx038_9049:9049',
#  'pa-blr-lnx043_9097:9097',
#  'pa-blr-lnx043_9022:9022',
#  'pa-blr-lnx038_9040:9040',
#  'pa-blr-lnx043_9091:9091',
#  'pa-blr-lnx042_9095:9095',
#  'pa-blr-lnx037_9026:9026',
#  'pa-blr-lnx043_9023:9023',
#  'pa-blr-lnx037_9035:9035',
#  'pa-blr-lnx038_9084:9084',
#  'pa-blr-lnx038_9016:9016',
#  'pa-blr-lnx038_9075:9075',
#  'pa-blr-lnx043_9008:9008',
#  'pa-blr-lnx037_9063:9063',
#  'pa-blr-lnx044_9026:9026',
#  'pa-blr-lnx038_9092:9092',
#  'pa-blr-lnx043_9077:9077',
#  'pa-blr-lnx038_9081:9081',
#  'pa-blr-lnx038_9037:9037',
#  'pa-blr-lnx041_9038:9038',
#  'pa-blr-lnx037_9100:9100',
#  'pa-blr-lnx043_9012:9012',
#  'pa-blr-lnx038_9014:9014',
#  'pa-blr-lnx041_9069:9069',
#  'pa-blr-lnx038_9059:9059',
#  'pa-blr-lnx041_9042:9042',
#  'pa-blr-lnx043_9085:9085',
#  'pa-blr-lnx041_9040:9040',
#  'pa-blr-lnx041_9032:9032',
#  'pa-blr-lnx043_9059:9059',
#  'pa-blr-lnx044_9055:9055',
#  'pa-blr-lnx041_9048:9048',
#  'pa-blr-lnx043_9095:9095',
#  'pa-blr-lnx038_9027:9027',
#  'pa-blr-lnx041_9066:9066',
#  'pa-blr-lnx043_9037:9037',
#  'pa-blr-lnx040_9092:9092',
#  'pa-blr-lnx043_9032:9032',
#  'pa-blr-lnx038_9077:9077',
#  'pa-blr-lnx043_9045:9045',
#  'pa-blr-lnx044_9022:9022',
#  'pa-blr-lnx043_9071:9071',
#  'pa-blr-lnx041_9095:9095',
#  'pa-blr-lnx041_9022:9022',
#  'pa-blr-lnx044_9041:9041',
#  'pa-blr-lnx044_9090:9090',
#  'pa-blr-lnx037_9049:9049',
#  'pa-blr-lnx038_9080:9080',
#  'pa-blr-lnx043_9042:9042',
#  'pa-blr-lnx037_9074:9074',
#  'pa-blr-lnx041_9083:9083',
#  'pa-blr-lnx043_9007:9007',
#  'pa-blr-lnx037_9094:9094',
#  'pa-blr-lnx038_9091:9091',
#  'pa-blr-lnx043_9046:9046',
#  'pa-blr-lnx038_9039:9039',
#  'pa-blr-lnx038_9038:9038',
#  'pa-blr-lnx038_9033:9033',
#  'pa-blr-lnx037_9069:9069',
#  'pa-blr-lnx037_9062:9062',
#  'pa-blr-lnx037_9039:9039',
#  'pa-blr-lnx043_9067:9067',
#  'pa-blr-lnx042_9080:9080',
#  'pa-blr-lnx038_9079:9079',
#  'pa-blr-lnx038_9096:9096',
#  'pa-blr-lnx043_9064:9064',
#  'pa-blr-lnx040_9028:9028',
#  'pa-blr-lnx043_9004:9004',
#  'pa-blr-lnx043_9080:9080',
#  'pa-blr-lnx043_9017:9017',
#  'pa-blr-lnx044_9024:9024',
#  'pa-blr-lnx042_9001:9001',
#  'pa-blr-lnx037_9011:9011',
#  'pa-blr-lnx041_9044:9044',
#  'pa-blr-lnx044_9031:9031',
#  'pa-blr-lnx043_9035:9035',
#  'pa-blr-lnx041_9096:9096',
#  'pa-blr-lnx038_9031:9031',
#  'pa-blr-lnx042_9010:9010',
#  'pa-blr-lnx038_9009:9009',
#  'pa-blr-lnx045_9099:9099',
#  'pa-blr-lnx044_9086:9086',
#  'pa-blr-lnx038_9076:9076',
#  'pa-blr-lnx045_9058:9058',
#  'pa-blr-lnx037_9076:9076',
#  'pa-blr-lnx043_9039:9039',
#  'pa-blr-lnx043_9047:9047',
#  'pa-blr-lnx041_9029:9029',
#  'pa-blr-lnx041_9037:9037',
#  'pa-blr-lnx038_9024:9024',
#  'pa-blr-lnx038_9054:9054',
#  'pa-blr-lnx043_9030:9030',
#  'pa-blr-lnx043_9040:9040',
#  'pa-blr-lnx041_9008:9008',
#  'pa-blr-lnx041_9092:9092',
#  'pa-blr-lnx037_9052:9052',
#  'pa-blr-lnx044_9030:9030',
#  'pa-blr-lnx043_9054:9054',
#  'pa-blr-lnx043_9070:9070',
#  'pa-blr-lnx038_9090:9090',
#  'pa-blr-lnx043_9081:9081',
#  'pa-blr-lnx038_9022:9022',
#  'pa-blr-lnx043_9048:9048',
#  'pa-blr-lnx041_9012:9012',
#  'pa-blr-lnx038_9008:9008',
#  'pa-blr-lnx037_9012:9012',
#  'pa-blr-lnx041_9065:9065',
#  'pa-blr-lnx041_9043:9043',
#  'pa-blr-lnx041_9074:9074',
#  'pa-blr-lnx044_9025:9025',
#  'pa-blr-lnx043_9093:9093',
#  'pa-blr-lnx043_9018:9018',
#  'pa-blr-lnx039_9016:9016',
#  'pa-blr-lnx043_9019:9019',
#  'pa-blr-lnx037_9050:9050',
#  'pa-blr-lnx041_9097:9097',
#  'pa-blr-lnx044_9032:9032',
#  'pa-blr-lnx043_9076:9076',
#  'pa-blr-lnx037_9073:9073',
#  'pa-blr-lnx043_9036:9036',
#  'pa-blr-lnx037_9042:9042',
#  'pa-blr-lnx037_9016:9016',
#  'pa-blr-lnx042_9047:9047',
#  'pa-blr-lnx044_9027:9027',
#  'pa-blr-lnx040_9065:9065',
#  'pa-blr-lnx043_9072:9072',
#  'pa-blr-lnx043_9100:9100',
#  'pa-blr-lnx043_9010:9010',
#  'pa-blr-lnx044_9017:9017',
#  'pa-blr-lnx044_9019:9019',
#  'pa-blr-lnx039_9078:9078',
#  'pa-blr-lnx042_9040:9040',
#  'pa-blr-lnx041_9001:9001',
#  'pa-blr-lnx044_9014:9014',
#  'pa-blr-lnx041_9011:9011',
#  'pa-blr-lnx041_9045:9045',
#  'pa-blr-lnx043_9094:9094',
#  'pa-blr-lnx043_9016:9016',
#  'pa-blr-lnx041_9026:9026',
#  'pa-blr-lnx041_9013:9013',
#  'pa-blr-lnx041_9033:9033',
#  'pa-blr-lnx041_9064:9064',
#  'pa-blr-lnx042_9053:9053',
#  'pa-blr-lnx041_9003:9003',
#  'pa-blr-lnx044_9088:9088',
#  'pa-blr-lnx042_9015:9015',
#  'pa-blr-lnx041_9009:9009',
#  'pa-blr-lnx041_9007:9007',
#  'pa-blr-lnx044_9005:9005',
#  'pa-blr-lnx039_9053:9053',
#  'pa-blr-lnx044_9050:9050',
#  'pa-blr-lnx044_9082:9082',
#  'pa-blr-lnx041_9030:9030',
#  'pa-blr-lnx041_9055:9055',
#  'pa-blr-lnx040_9098:9098',
#  'pa-blr-lnx041_9015:9015',
#  'pa-blr-lnx041_9014:9014',
#  'pa-blr-lnx042_9009:9009',
#  'pa-blr-lnx044_9078:9078',
#  'pa-blr-lnx044_9023:9023',
#  'pa-blr-lnx040_9090:9090',
#  'pa-blr-lnx042_9074:9074',
#  'pa-blr-lnx041_9005:9005',
#  'pa-blr-lnx039_9045:9045',
#  'pa-blr-lnx039_9006:9006',
#  'pa-blr-lnx044_9043:9043',
#  'pa-blr-lnx041_9025:9025',
#  'pa-blr-lnx038_9057:9057',
#  'pa-blr-lnx038_9095:9095',
#  'pa-blr-lnx044_9040:9040',
#  'pa-blr-lnx045_9010:9010',
#  'pa-blr-lnx040_9055:9055',
#  'pa-blr-lnx042_9075:9075',
#  'pa-blr-lnx041_9093:9093',
#  'pa-blr-lnx041_9027:9027',
#  'pa-blr-lnx042_9031:9031',
#  'pa-blr-lnx045_9075:9075',
#  'pa-blr-lnx039_9094:9094',
#  'pa-blr-lnx037_9089:9089',
#  'pa-blr-lnx038_9087:9087',
#  'pa-blr-lnx044_9048:9048',
#  'pa-blr-lnx042_9025:9025',
#  'pa-blr-lnx038_9051:9051',
#  'pa-blr-lnx041_9086:9086',
#  'pa-blr-lnx038_9086:9086',
#  'pa-blr-lnx042_9006:9006',
#  'pa-blr-lnx043_9062:9062',
#  'pa-blr-lnx045_9046:9046',
#  'pa-blr-lnx038_9053:9053',
#  'pa-blr-lnx044_9044:9044',
#  'pa-blr-lnx044_9016:9016',
#  'pa-blr-lnx041_9002:9002',
#  'pa-blr-lnx045_9042:9042',
#  'pa-blr-lnx044_9059:9059',
#  'pa-blr-lnx044_9093:9093',
#  'pa-blr-lnx044_9028:9028',
#  'pa-blr-lnx042_9063:9063',
#  'pa-blr-lnx041_9080:9080',
#  'pa-blr-lnx043_9086:9086',
#  'pa-blr-lnx041_9047:9047',
#  'pa-blr-lnx038_9089:9089',
#  'pa-blr-lnx044_9065:9065',
#  'pa-blr-lnx044_9070:9070',
#  'pa-blr-lnx041_9010:9010',
#  'pa-blr-lnx044_9064:9064',
#  'pa-blr-lnx042_9042:9042',
#  'pa-blr-lnx044_9008:9008',
#  'pa-blr-lnx041_9036:9036',
#  'pa-blr-lnx041_9039:9039',
#  'pa-blr-lnx041_9004:9004',
#  'pa-blr-lnx045_9028:9028',
#  'pa-blr-lnx041_9041:9041',
#  'pa-blr-lnx040_9051:9051',
#  'pa-blr-lnx044_9052:9052',
#  'pa-blr-lnx043_9026:9026',
#  'pa-blr-lnx039_9056:9056',
#  'pa-blr-lnx043_9006:9006',
#  'pa-blr-lnx040_9083:9083',
#  'pa-blr-lnx039_9085:9085',
#  'pa-blr-lnx044_9099:9099',
#  'pa-blr-lnx042_9059:9059',
#  'pa-blr-lnx039_9062:9062',
#  'pa-blr-lnx043_9020:9020',
#  'pa-blr-lnx037_9019:9019',
#  'pa-blr-lnx041_9049:9049',
#  'pa-blr-lnx042_9049:9049',
#  'pa-blr-lnx039_9022:9022',
#  'pa-blr-lnx040_9081:9081',
#  'pa-blr-lnx042_9088:9088',
#  'pa-blr-lnx042_9092:9092',
#  'pa-blr-lnx041_9052:9052',
#  'pa-blr-lnx041_9059:9059',
#  'pa-blr-lnx042_9078:9078',
#  'pa-blr-lnx040_9027:9027',
#  'pa-blr-lnx044_9094:9094',
#  'pa-blr-lnx041_9081:9081',
#  'pa-blr-lnx044_9036:9036',
#  'pa-blr-lnx037_9013:9013',
#  'pa-blr-lnx039_9019:9019',
#  'pa-blr-lnx045_9013:9013',
#  'pa-blr-lnx045_9026:9026',
#  'pa-blr-lnx044_9037:9037',
#  'pa-blr-lnx042_9062:9062',
#  'pa-blr-lnx041_9100:9100',
#  'pa-blr-lnx040_9016:9016',
#  'pa-blr-lnx041_9062:9062',
#  'pa-blr-lnx044_9029:9029',
#  'pa-blr-lnx040_9075:9075',
#  'pa-blr-lnx041_9089:9089',
#  'pa-blr-lnx045_9097:9097',
#  'pa-blr-lnx044_9001:9001',
#  'pa-blr-lnx044_9011:9011',
#  'pa-blr-lnx044_9097:9097',
#  'pa-blr-lnx041_9071:9071',
#  'pa-blr-lnx037_9097:9097',
#  'pa-blr-lnx037_9044:9044',
#  'pa-blr-lnx037_9002:9002',
#  'pa-blr-lnx040_9037:9037',
#  'pa-blr-lnx041_9087:9087',
#  'pa-blr-lnx040_9026:9026',
#  'pa-blr-lnx045_9050:9050',
#  'pa-blr-lnx041_9016:9016',
#  'pa-blr-lnx041_9088:9088',
#  'pa-blr-lnx044_9034:9034',
#  'pa-blr-lnx040_9007:9007',
#  'pa-blr-lnx040_9015:9015',
#  'pa-blr-lnx037_9055:9055',
#  'pa-blr-lnx040_9008:9008',
#  'pa-blr-lnx040_9070:9070',
#  'pa-blr-lnx045_9082:9082',
#  'pa-blr-lnx038_9069:9069',
#  'pa-blr-lnx039_9014:9014',
#  'pa-blr-lnx041_9073:9073',
#  'pa-blr-lnx045_9056:9056',
#  'pa-blr-lnx039_9082:9082',
#  'pa-blr-lnx045_9077:9077',
#  'pa-blr-lnx041_9068:9068',
#  'pa-blr-lnx039_9074:9074',
#  'pa-blr-lnx039_9051:9051',
#  'pa-blr-lnx039_9076:9076',
#  'pa-blr-lnx045_9044:9044',
#  'pa-blr-lnx044_9054:9054',
#  'pa-blr-lnx038_9030:9030',
#  'pa-blr-lnx044_9051:9051',
#  'pa-blr-lnx041_9094:9094',
#  'pa-blr-lnx039_9030:9030',
#  'pa-blr-lnx045_9018:9018',
#  'pa-blr-lnx045_9055:9055',
#  'pa-blr-lnx044_9035:9035',
#  'pa-blr-lnx041_9031:9031',
#  'pa-blr-lnx044_9012:9012',
#  'pa-blr-lnx037_9057:9057',
#  'pa-blr-lnx045_9049:9049',
#  'pa-blr-lnx045_9015:9015',
#  'pa-blr-lnx037_9048:9048',
#  'pa-blr-lnx044_9067:9067',
#  'pa-blr-lnx041_9054:9054',
#  'pa-blr-lnx045_9022:9022',
#  'pa-blr-lnx044_9096:9096',
#  'pa-blr-lnx040_9096:9096',
#  'pa-blr-lnx039_9059:9059',
#  'pa-blr-lnx037_9010:9010',
#  'pa-blr-lnx041_9034:9034',
#  'pa-blr-lnx045_9064:9064',
#  'pa-blr-lnx042_9057:9057',
#  'pa-blr-lnx042_9016:9016',
#  'pa-blr-lnx040_9042:9042',
#  'pa-blr-lnx037_9093:9093',
#  'pa-blr-lnx042_9022:9022',
#  'pa-blr-lnx039_9083:9083',
#  'pa-blr-lnx039_9063:9063',
#  'pa-blr-lnx040_9074:9074',
#  'pa-blr-lnx044_9049:9049',
#  'pa-blr-lnx040_9084:9084',
#  'pa-blr-lnx039_9023:9023',
#  'pa-blr-lnx039_9069:9069',
#  'pa-blr-lnx045_9006:9006',
#  'pa-blr-lnx045_9032:9032',
#  'pa-blr-lnx045_9040:9040',
#  'pa-blr-lnx039_9064:9064',
#  'pa-blr-lnx039_9077:9077',
#  'pa-blr-lnx039_9067:9067',
#  'pa-blr-lnx044_9081:9081',
#  'pa-blr-lnx044_9057:9057',
#  'pa-blr-lnx040_9006:9006',
#  'pa-blr-lnx045_9070:9070',
#  'pa-blr-lnx045_9084:9084',
#  'pa-blr-lnx045_9051:9051',
#  'pa-blr-lnx040_9072:9072',
#  'pa-blr-lnx045_9011:9011',
#  'pa-blr-lnx037_9088:9088',
#  'pa-blr-lnx045_9039:9039',
#  'pa-blr-lnx041_9046:9046',
#  'pa-blr-lnx041_9072:9072',
#  'pa-blr-lnx037_9079:9079',
#  'pa-blr-lnx045_9033:9033',
#  'pa-blr-lnx039_9089:9089',
#  'pa-blr-lnx039_9003:9003',
#  'pa-blr-lnx045_9003:9003',
#  'pa-blr-lnx040_9077:9077',
#  'pa-blr-lnx039_9073:9073',
#  'pa-blr-lnx037_9084:9084',
#  'pa-blr-lnx045_9025:9025',
#  'pa-blr-lnx042_9021:9021',
#  'pa-blr-lnx039_9021:9021',
#  'pa-blr-lnx040_9063:9063',
#  'pa-blr-lnx039_9097:9097',
#  'pa-blr-lnx039_9013:9013',
#  'pa-blr-lnx040_9025:9025',
#  'pa-blr-lnx038_9023:9023',
#  'pa-blr-lnx045_9093:9093',
#  'pa-blr-lnx045_9024:9024',
#  'pa-blr-lnx039_9004:9004',
#  'pa-blr-lnx040_9045:9045',
#  'pa-blr-lnx037_9023:9023',
#  'pa-blr-lnx038_9034:9034',
#  'pa-blr-lnx045_9045:9045',
#  'pa-blr-lnx045_9100:9100',
#  'pa-blr-lnx039_9068:9068',
#  'pa-blr-lnx045_9069:9069',
#  'pa-blr-lnx039_9046:9046',
#  'pa-blr-lnx039_9070:9070',
#  'pa-blr-lnx045_9085:9085',
#  'pa-blr-lnx045_9068:9068',
#  'pa-blr-lnx039_9091:9091',
#  'pa-blr-lnx045_9029:9029',
#  'pa-blr-lnx039_9050:9050',
#  'pa-blr-lnx045_9098:9098',
#  'pa-blr-lnx041_9075:9075',
#  'pa-blr-lnx041_9018:9018',
#  'pa-blr-lnx040_9078:9078',
#  'pa-blr-lnx044_9010:9010',
#  'pa-blr-lnx044_9083:9083',
#  'pa-blr-lnx044_9003:9003',
#  'pa-blr-lnx040_9057:9057',
#  'pa-blr-lnx045_9083:9083',
#  'pa-blr-lnx039_9043:9043',
#  'pa-blr-lnx045_9071:9071',
#  'pa-blr-lnx039_9041:9041',
#  'pa-blr-lnx039_9086:9086',
#  'pa-blr-lnx045_9066:9066',
#  'pa-blr-lnx045_9089:9089',
#  'pa-blr-lnx045_9048:9048',
#  'pa-blr-lnx045_9014:9014',
#  'pa-blr-lnx039_9075:9075',
#  'pa-blr-lnx040_9033:9033',
#  'pa-blr-lnx045_9043:9043',
#  'pa-blr-lnx039_9027:9027',
#  'pa-blr-lnx037_9038:9038',
#  'pa-blr-lnx039_9035:9035',
#  'pa-blr-lnx045_9079:9079',
#  'pa-blr-lnx039_9090:9090',
#  'pa-blr-lnx037_9024:9024',
#  'pa-blr-lnx039_9095:9095',
#  'pa-blr-lnx042_9011:9011',
#  'pa-blr-lnx040_9091:9091',
#  'pa-blr-lnx045_9021:9021',
#  'pa-blr-lnx044_9004:9004',
#  'pa-blr-lnx040_9040:9040',
#  'pa-blr-lnx039_9061:9061',
#  'pa-blr-lnx042_9073:9073',
#  'pa-blr-lnx045_9007:9007',
#  'pa-blr-lnx045_9061:9061',
#  'pa-blr-lnx039_9100:9100',
#  'pa-blr-lnx045_9035:9035',
#  'pa-blr-lnx039_9020:9020',
#  'pa-blr-lnx037_9031:9031',
#  'pa-blr-lnx045_9076:9076',
#  'pa-blr-lnx039_9038:9038',
#  'pa-blr-lnx040_9020:9020',
#  'pa-blr-lnx037_9043:9043',
#  'pa-blr-lnx042_9043:9043',
#  'pa-blr-lnx045_9009:9009',
#  'pa-blr-lnx042_9055:9055',
#  'pa-blr-lnx044_9061:9061',
#  'pa-blr-lnx040_9076:9076',
#  'pa-blr-lnx039_9024:9024',
#  'pa-blr-lnx045_9052:9052',
#  'pa-blr-lnx045_9001:9001',
#  'pa-blr-lnx045_9047:9047',
#  'pa-blr-lnx039_9087:9087',
#  'pa-blr-lnx040_9017:9017',
#  'pa-blr-lnx045_9096:9096',
#  'pa-blr-lnx040_9003:9003',
#  'pa-blr-lnx039_9034:9034',
#  'pa-blr-lnx040_9038:9038',
#  'pa-blr-lnx040_9082:9082',
#  'pa-blr-lnx045_9004:9004',
#  'pa-blr-lnx039_9037:9037',
#  'pa-blr-lnx039_9017:9017',
#  'pa-blr-lnx045_9041:9041',
#  'pa-blr-lnx042_9048:9048',
#  'pa-blr-lnx045_9078:9078',
#  'pa-blr-lnx039_9052:9052',
#  'pa-blr-lnx045_9059:9059',
#  'pa-blr-lnx045_9002:9002',
#  'pa-blr-lnx045_9020:9020',
#  'pa-blr-lnx042_9089:9089',
#  'pa-blr-lnx040_9099:9099',
#  'pa-blr-lnx039_9042:9042',
#  'pa-blr-lnx042_9013:9013',
#  'pa-blr-lnx039_9029:9029',
#  'pa-blr-lnx040_9036:9036',
#  'pa-blr-lnx039_9081:9081',
#  'pa-blr-lnx039_9010:9010',
#  'pa-blr-lnx045_9095:9095',
#  'pa-blr-lnx045_9067:9067',
#  'pa-blr-lnx043_9066:9066',
#  'pa-blr-lnx043_9051:9051',
#  'pa-blr-lnx040_9079:9079',
#  'pa-blr-lnx037_9075:9075',
#  'pa-blr-lnx045_9023:9023',
#  'pa-blr-lnx045_9065:9065',
#  'pa-blr-lnx039_9065:9065',
#  'pa-blr-lnx045_9019:9019',
#  'pa-blr-lnx045_9034:9034',
#  'pa-blr-lnx040_9071:9071',
#  'pa-blr-lnx042_9008:9008',
#  'pa-blr-lnx045_9008:9008',
#  'pa-blr-lnx040_9087:9087',
#  'pa-blr-lnx039_9096:9096',
#  'pa-blr-lnx045_9060:9060',
#  'pa-blr-lnx039_9002:9002',
#  'pa-blr-lnx039_9092:9092',
#  'pa-blr-lnx045_9091:9091',
#  'pa-blr-lnx040_9013:9013',
#  'pa-blr-lnx040_9041:9041',
#  'pa-blr-lnx039_9033:9033',
#  'pa-blr-lnx045_9062:9062',
#  'pa-blr-lnx040_9067:9067',
#  'pa-blr-lnx045_9063:9063',
#  'pa-blr-lnx045_9030:9030',
#  'pa-blr-lnx039_9040:9040',
#  'pa-blr-lnx040_9002:9002',
#  'pa-blr-lnx040_9039:9039',
#  'pa-blr-lnx045_9016:9016',
#  'pa-blr-lnx042_9100:9100',
#  'pa-blr-lnx042_9052:9052',
#  'pa-blr-lnx039_9057:9057',
#  'pa-blr-lnx040_9068:9068',
#  'pa-blr-lnx037_9014:9014',
#  'pa-blr-lnx039_9044:9044',
#  'pa-blr-lnx039_9048:9048',
#  'pa-blr-lnx043_9043:9043',
#  'pa-blr-lnx042_9076:9076',
#  'pa-blr-lnx040_9093:9093',
#  'pa-blr-lnx045_9031:9031',
#  'pa-blr-lnx040_9088:9088',
#  'pa-blr-lnx045_9053:9053',
#  'pa-blr-lnx042_9020:9020',
#  'pa-blr-lnx045_9073:9073',
#  'pa-blr-lnx045_9054:9054',
#  'pa-blr-lnx045_9074:9074',
#  'pa-blr-lnx040_9061:9061',
#  'pa-blr-lnx039_9008:9008',
#  'pa-blr-lnx039_9049:9049',
#  'pa-blr-lnx040_9097:9097',
#  'pa-blr-lnx040_9035:9035',
#  'pa-blr-lnx039_9099:9099',
#  'pa-blr-lnx037_9058:9058',
#  'pa-blr-lnx040_9089:9089',
#  'pa-blr-lnx045_9036:9036',
#  'pa-blr-lnx042_9070:9070',
#  'pa-blr-lnx040_9058:9058',
#  'pa-blr-lnx039_9060:9060',
#  'pa-blr-lnx037_9068:9068',
#  'pa-blr-lnx039_9031:9031',
#  ...]

# %%
kmRepository = KMRepository.get(cachedir="../cache")

solutionPackManager = SolutionPackManager(path="solutions", repository = kmRepository)
rulesets = RuleSetFactory(["/Users/martin/Development/pcm2cma/in/pconfig/activ"])

rulesetMigrator = RulesetMigrator(rulesets, solutionPackManager, kmRepository)
rulesetConfigurations = rulesetMigrator.migrate()
# Out:
# 2020-09-09 17:30:22,820 - lib.kmrepository - INFO - Loading KM repository from cache '../cache/abc' ...
# 2020-09-09 17:30:23,122 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827947_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:23,147 - lib.ruleset - ERROR - Found unexpected token 'with' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827930_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:23,148 - lib.ruleset - ERROR - Found unexpected token 'with' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827931_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:23,776 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827951_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:24,086 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827957_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:24,100 - lib.ruleset - ERROR - Ruleset file '/Users/martin/Development/pcm2cma/in/pconfig/activ/.cfg' does not match file naming convention.
# 2020-09-09 17:30:25,128 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827940_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:25,151 - lib.ruleset - ERROR - Found unexpected token 'from' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827936_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:25,427 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827959_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:25,476 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827945_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:25,479 - lib.ruleset - ERROR - Found unexpected token 'with' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827933_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:25,568 - lib.ruleset - ERROR - Found unexpected token 'from' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827938_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:25,637 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827948_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:26,029 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827960_3181.cfg' at 1. Expected '='.
# 2020-09-09 17:30:26,030 - lib.ruleset - ERROR - Found unexpected token 'open' in '/Users/martin/Development/pcm2cma/in/pconfig/activ/hst1827961_3181.cfg' at 1. Expected '='.

# %%
a={"a": {"b":"b"}, "c":{"d":"d"}}

# %%
for i in a:
    print(i)
# Out:
# a
# c

# %%
import time
int(time.time())
# Out:
# 1600425631
