# %%
import pandas as pd
import numpy as np

import sys
sys.path.append("..")
from lib.thresholds import FileThresholdSet, InstanceThresholdMigrator
from lib.kmrepository import KMRepository
from lib.policy import PolicyFactory

# %%
kmRepository = KMRepository.get(cachedir="../cache")

thresholds = FileThresholdSet(["/Users/martin/Downloads/tsim-blr-win01_AllInstanceThresholdSettings_2020_07_26_19_15_45.csv"])
thresholds.load()
migrator = InstanceThresholdMigrator(thresholds, kmRepository)
agentConfigurations = migrator.migrate()

policyFactory = PolicyFactory("*", "*", False, False, 399, "admin", "administrators")
# Out:
# 2020-09-03 15:45:50,340 - lib.kmrepository - INFO - Loading KM repository from cache '../cache/abc' ...
# 2020-09-03 15:45:50,352 - lib.thresholds - INFO - Loading Server Thresholds from '/Users/martin/Downloads/tsim-blr-win01_AllInstanceThresholdSettings_2020_07_26_19_15_45.csv' ...
# 2020-09-03 15:45:50,670 - lib.thresholds - INFO - Migrating 61329 instance thresholds ...

# %%
(configurationMatrix, uniqueConfigurations, id) = policyFactory.optimize(agentConfigurations)
# Out:
# 2020-09-03 15:45:56,380 - lib.policy - INFO - Optimizing policies for 2543 agents ...
# 2020-09-03 15:45:56,381 - lib.policy - INFO - Found 27 unique configurations.
# 2020-09-03 15:46:01,913 - lib.policy - INFO - top 5 duplicate agents with same configuration:
# 2020-09-03 15:46:01,916 - lib.policy - INFO - AgentId 'pa-blr-lnx104_9078:9078' has 2186 duplicates.
# 2020-09-03 15:46:01,916 - lib.policy - INFO - AgentId 'pa-blr-lnx045_9024:9024' has 0 duplicates.
# 2020-09-03 15:46:01,917 - lib.policy - INFO - AgentId 'pa-blr-lnx039_9068:9068' has 0 duplicates.
# 2020-09-03 15:46:01,918 - lib.policy - INFO - AgentId 'pa-blr-lnx045_9100:9100' has 0 duplicates.
# 2020-09-03 15:46:01,918 - lib.policy - INFO - AgentId 'pa-blr-lnx045_9045:9045' has 0 duplicates.

# %%
configurationMatrix
# Out:
#     pa-blr-lnx104_9078:9078  pa-blr-lnx108_9013:9013  pa-blr-lnx102_9083:9083  \
# 0                      True                     True                     True
# 1                      True                     True                     True
# 2                      True                     True                     True
# 3                      True                     True                     True
# 4                      True                     True                     True
# 5                      True                     True                     True
# 6                      True                     True                     True
# 7                      True                     True                     True
# 8                      True                     True                     True
# 9                      True                     True                     True
# 10                     True                     True                     True
# 11                     True                     True                     True
# 12                     True                     True                     True
# 13                     True                     True                     True
# 14                     True                     True                     True
# 15                     True                     True                     True
# 16                     True                     True                     True
# 17                     True                     True                     True
# 18                     True                     True                     True
# 19                     True                     True                     True
# 20                     True                     True                     True
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx103_9033:9033  pa-blr-lnx101_9087:9087  pa-blr-lnx105_9092:9092  \
# 0                      True                     True                     True
# 1                      True                     True                     True
# 2                      True                     True                     True
# 3                      True                     True                     True
# 4                      True                     True                     True
# 5                      True                     True                     True
# 6                      True                     True                     True
# 7                      True                     True                     True
# 8                      True                     True                     True
# 9                      True                     True                     True
# 10                     True                     True                     True
# 11                     True                     True                     True
# 12                     True                     True                     True
# 13                     True                     True                     True
# 14                     True                     True                     True
# 15                     True                     True                     True
# 16                     True                     True                     True
# 17                     True                     True                     True
# 18                     True                     True                     True
# 19                     True                     True                     True
# 20                     True                     True                     True
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx101_9016:9016  pa-blr-lnx106_9027:9027  pa-blr-lnx103_9014:9014  \
# 0                      True                     True                     True
# 1                      True                     True                     True
# 2                      True                     True                     True
# 3                      True                     True                     True
# 4                      True                     True                     True
# 5                      True                     True                     True
# 6                      True                     True                     True
# 7                      True                     True                     True
# 8                      True                     True                     True
# 9                      True                     True                     True
# 10                     True                     True                     True
# 11                     True                     True                     True
# 12                     True                     True                     True
# 13                     True                     True                     True
# 14                     True                     True                     True
# 15                     True                     True                     True
# 16                     True                     True                     True
# 17                     True                     True                     True
# 18                     True                     True                     True
# 19                     True                     True                     True
# 20                     True                     True                     True
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx106_9061:9061  ...  pa-blr-lnx107_9058:9058  \
# 0                      True  ...                    False
# 1                      True  ...                    False
# 2                      True  ...                    False
# 3                      True  ...                    False
# 4                      True  ...                    False
# 5                      True  ...                    False
# 6                      True  ...                    False
# 7                      True  ...                    False
# 8                      True  ...                    False
# 9                      True  ...                    False
# 10                     True  ...                    False
# 11                     True  ...                    False
# 12                     True  ...                    False
# 13                     True  ...                    False
# 14                     True  ...                    False
# 15                     True  ...                    False
# 16                     True  ...                    False
# 17                     True  ...                    False
# 18                     True  ...                    False
# 19                     True  ...                    False
# 20                     True  ...                    False
# 21                     True  ...                     True
# 22                     True  ...                     True
# 23                     True  ...                     True
# 24                     True  ...                     True
# 25                     True  ...                     True
# 26                     True  ...                     True
#
#     pa-blr-lnx104_9003:9003  pa-blr-lnx101_9053:9053  pa-blr-lnx100_9032:9032  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
# 10                    False                    False                    False
# 11                    False                    False                    False
# 12                    False                    False                    False
# 13                    False                    False                    False
# 14                    False                    False                    False
# 15                    False                    False                    False
# 16                    False                    False                    False
# 17                    False                    False                    False
# 18                    False                    False                    False
# 19                    False                    False                    False
# 20                    False                    False                    False
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx102_9068:9068  pa-blr-lnx104_9062:9062  pa-blr-lnx102_9097:9097  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
# 10                    False                    False                    False
# 11                    False                    False                    False
# 12                    False                    False                    False
# 13                    False                    False                    False
# 14                    False                    False                    False
# 15                    False                    False                    False
# 16                    False                    False                    False
# 17                    False                    False                    False
# 18                    False                    False                    False
# 19                    False                    False                    False
# 20                    False                    False                    False
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
#     pa-blr-lnx102_9059:9059  pa-blr-lnx104_9099:9099  pa-blr-lnx100_9081:9081
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
# 10                    False                    False                    False
# 11                    False                    False                    False
# 12                    False                    False                    False
# 13                    False                    False                    False
# 14                    False                    False                    False
# 15                    False                    False                    False
# 16                    False                    False                    False
# 17                    False                    False                    False
# 18                    False                    False                    False
# 19                    False                    False                    False
# 20                    False                    False                    False
# 21                     True                     True                     True
# 22                     True                     True                     True
# 23                     True                     True                     True
# 24                     True                     True                     True
# 25                     True                     True                     True
# 26                     True                     True                     True
#
# [27 rows x 2543 columns]

# %%
configurationMatrix.loc[[1,2],['pa-blr-lnx104_9078:9078','pa-blr-lnx103_9033:9033' ]]
# Out:
#    pa-blr-lnx104_9078:9078  pa-blr-lnx103_9033:9033
# 1                     True                     True
# 2                     True                     True

# %%
pd.Series()

# %%
d = pd.DataFrame(data=[[True, False],[True, True]])

# %%
all(d[1])
# Out:
# False

# %%
d = pd.DataFrame(columns=["config", "variant", "id1", "id2"])

# %%
d.insert(column="id3", value=1, loc=2)

# %%
d
# Out:
# Empty DataFrame
# Columns: [config, variant, id3, id1, id2]
# Index: []
